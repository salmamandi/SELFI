# %% [markdown]
# ##### It encodes all the categorical features in our dataset to binary array, and drops unwanted feature columns. And creates final dataset.

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd

# %%
user_no=12
df = pd.read_csv('/content/drive/MyDrive/InputFolder/NewData/Output2/user_'+str(user_no)+'.csv')

# %%
dfencoded = df[['SmileValue','EyeglassesValue','SunglassesValue','GenderValue','BeardValue','MustacheValue','EyesOpenValue','MouthOpenValue']]
dfencoded
# Out:
#     SmileValue EyeglassesValue SunglassesValue GenderValue BeardValue  \
# 0        False           False           False    'Female'      False
# 1        False           False           False    'Female'      False
# 2        False           False           False    'Female'      False
# 3        False           False           False    'Female'      False
# 4        False           False           False    'Female'      False
# ..         ...             ...             ...         ...        ...
# 404      False           False           False    'Female'      False
# 405      False           False           False    'Female'      False
# 406      False           False           False    'Female'      False
# 407       True           False           False    'Female'      False
# 408       True           False           False    'Female'      False
#
#     MustacheValue EyesOpenValue MouthOpenValue
# 0           False          True          False
# ...

# %%
from sklearn.preprocessing import OneHotEncoder 
ohc = OneHotEncoder(handle_unknown='ignore')
data = ohc.fit_transform(dfencoded).toarray()

# %%
df_encoded = pd.DataFrame(data = data,columns =ohc.get_feature_names(['SmileValue','EyeglassesValue','SunglassesValue','GenderValue','BeardValue','MustacheValue','EyesOpenValue','MouthOpenValue']) )
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
df =  pd.concat([df,df_encoded],axis = 1)

# %%
df
# Out:
#                             FileName  \
# 0    user_22/IMG_20210820_123021.jpg
# 1    user_22/IMG_20210820_123023.jpg
# 2    user_22/IMG_20210821_184544.jpg
# 3    user_22/IMG_20210821_184556.jpg
# 4    user_22/IMG_20210821_184557.jpg
# ..                               ...
# 404  user_22/IMG_20220407_124647.jpg
# 405  user_22/IMG_20220407_124648.jpg
# 406  user_22/IMG_20220407_153413.jpg
# 407  user_22/IMG_20220407_213215.jpg
# 408  user_22/IMG_20220407_213216.jpg
#
#                                            BoundingBox  \
# 0    {'Width': 0.32883480191230774, 'Height': 0.355...
# 1    {'Width': 0.34279727935791016, 'Height': 0.365...
# 2    {'Width': 0.24113738536834717, 'Height': 0.221...
# 3    {'Width': 0.26312026381492615, 'Height': 0.225...
# 4    {'Width': 0.2710522711277008, 'Height': 0.2264...
# ..                                                 ...
# 404  {'Width': 0.3996994197368622, 'Height': 0.3933...
# 405  {'Width': 0.3458857238292694, 'Height': 0.3317...
# ...

# %%
df = df.drop(['BoundingBox','AgeRange','Smile','Eyeglasses','Sunglasses','Gender','Beard','Mustache','EyesOpen','MouthOpen','Emotions','Landmarks','Pose','Quality'],axis =1)
df = df.drop(['SmileValue','EyeglassesValue','SunglassesValue','GenderValue','BeardValue','MustacheValue','EyesOpenValue','MouthOpenValue'],axis = 1)
df = df.drop(['eyeLeft','eyeRight','mouthLeft','mouthRight','nose','leftEyeBrowLeft','leftEyeBrowRight','leftEyeBrowUp','rightEyeBrowLeft'],axis = 1)
df = df.drop(['rightEyeBrowRight','rightEyeBrowup','leftEyeLeft','leftEyeRight','leftEyeUp','leftEyeDown','rightEyeLeft','rightEyeRight','rightEyeUp','rightEyeDown','noseLeft','noseRight','mouthUp','mouthDown','leftPupil','rightPupil','upperJawlineLeft','midJawlineLeft','chinBottom','midJawlineRight','upperJawlineRight'],axis = 1)

# %%
df.to_csv('/content/drive/MyDrive/InputFolder/NewData/Output3/user_'+str(user_no)+'.csv',index = False)

# %%
# from sklearn import preprocessing
# lb = preprocessing.LabelBinarizer()
# lb.fit(df['PredictedEmotion'])

# %%
# datay = lb.transform(df['PredictedEmotion'])
# datay

# %%
# df = pd.DataFrame(data = datay,columns =lb.get_feature_names(['SmileValue','EyeglassesValue','SunglassesValue','GenderValue','BeardValue','MustacheValue','EyesOpenValue','MouthOpenValue']) )

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(df.drop(['FileName','PredictedEmotion','Target'],axis = 'columns'),df['Target'],test_size=0.2)

# %%
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier(n_estimators = 50)
# model.fit(x_train, y_train)

# %%
# model.score(x_test,y_test)
