# %% [markdown]
# ##### It pre-processes the feature dataset. it breaks down the complex features into separate columns.

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
user_no=12
df = pd.read_csv('/content/drive/MyDrive/InputFolder/NewData/Output1/user_'+str(user_no)+'.csv')

# %%
df[['BoundingBoxWidth','BoundingBoxHeight','BoundingBoxLeft','BoundingBoxTop']] = df.BoundingBox.str.split(",",expand = True)

# %%
import re
for row in range(len(df['BoundingBoxHeight'])):
    df['BoundingBoxHeight'][row] = re.sub("[^\d\.]","",df['BoundingBoxHeight'][row])
    df['BoundingBoxLeft'][row]=re.sub("[^\d\.]","",df['BoundingBoxLeft'][row])
    df['BoundingBoxWidth'][row]=re.sub("[^\d\.]","",df['BoundingBoxWidth'][row])
    df['BoundingBoxTop'][row]=re.sub("[^\d\.]","",df['BoundingBoxTop'][row])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df[['AgeRangeLow','AgeRangeHigh']] = df.AgeRange.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['AgeRangeLow'][row] = re.sub("[^\d]","",df['AgeRangeLow'][row])
    df['AgeRangeHigh'][row]=re.sub("[^\d]","",df['AgeRangeHigh'][row])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df[['SmileValue','SmileConfidence']] = df.Smile.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['SmileConfidence'][row] = re.sub("[^\d\.]","",df['SmileConfidence'][row])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for row in range(len(df['BoundingBoxHeight'])):
    df['SmileValue'][row] = df['SmileValue'][row].split(':')[-1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df[['EyeglassesValue','EyeglassesConfidence']] = df.Eyeglasses.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['EyeglassesConfidence'][row] = re.sub("[^\d\.]","",df['EyeglassesConfidence'][row])
    df['EyeglassesValue'][row] = df['EyeglassesValue'][row].split(':')[-1]
    
df[['SunglassesValue','SunglassesConfidence']] = df.Sunglasses.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['SunglassesConfidence'][row] = re.sub("[^\d\.]","",df['SunglassesConfidence'][row])
    df['SunglassesValue'][row] = df['SunglassesValue'][row].split(':')[-1]

df[['GenderValue','GenderConfidence']] = df.Gender.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['GenderConfidence'][row] = re.sub("[^\d\.]","",df['GenderConfidence'][row])
    df['GenderValue'][row] = df['GenderValue'][row].split(':')[-1]

df[['BeardValue','BeardConfidence']] = df.Beard.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['BeardConfidence'][row] = re.sub("[^\d\.]","",df['BeardConfidence'][row])
    df['BeardValue'][row] = df['BeardValue'][row].split(':')[-1]

df[['MustacheValue','MustacheConfidence']] = df.Mustache.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['MustacheConfidence'][row] = re.sub("[^\d\.]","",df['MustacheConfidence'][row])
    df['MustacheValue'][row] = df['MustacheValue'][row].split(':')[-1]
    

df[['EyesOpenValue','EyesOpenConfidence']] = df.EyesOpen.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['EyesOpenConfidence'][row] = re.sub("[^\d\.]","",df['EyesOpenConfidence'][row])
    df['EyesOpenValue'][row] = df['EyesOpenValue'][row].split(':')[-1]
    

df[['MouthOpenValue','MouthOpenConfidence']] = df.MouthOpen.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])):
    df['MouthOpenConfidence'][row] = re.sub("[^\d\.]","",df['MouthOpenConfidence'][row])
    df['MouthOpenValue'][row] = df['MouthOpenValue'][row].split(':')[-1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df[['eyeLeft','eyeRight','mouthLeft','mouthRight','nose','leftEyeBrowLeft','leftEyeBrowRight','leftEyeBrowUp','rightEyeBrowLeft','rightEyeBrowRight','rightEyeBrowup','leftEyeLeft','leftEyeRight','leftEyeUp','leftEyeDown','rightEyeLeft','rightEyeRight','rightEyeUp','rightEyeDown','noseLeft','noseRight','mouthUp','mouthDown','leftPupil','rightPupil','upperJawlineLeft','midJawlineLeft','chinBottom','midJawlineRight','upperJawlineRight']] = df.Landmarks.str.split("},",expand = True)
df[['t1','eyeLeftX','eyeLeftY']] = df.eyeLeft.str.split(",",expand = True)
df[['t2','eyeRightX','eyeRightY']] = df.eyeRight.str.split(",",expand = True)
df[['t3','mouthLeftX','mouthLeftY']] = df.mouthLeft.str.split(",",expand = True)
df[['t4','mouthRightX','mouthRightY']] = df.mouthRight.str.split(",",expand = True)
df[['t5','noseX','noseY']] = df.nose.str.split(",",expand = True)
df[['t6','leftEyeBrowLeftX','leftEyeBrowLeftY']] = df.leftEyeBrowLeft.str.split(",",expand = True)
df[['t7','leftEyeBrowRightX','leftEyeBrowRightY']] = df.leftEyeBrowRight.str.split(",",expand = True)
df[['t8','leftEyeBrowUpX','leftEyeBrowUpY']] = df.leftEyeBrowUp.str.split(",",expand = True)
df[['t9','rightEyeBrowLeftX','rightEyeBrowLeftY']] = df.rightEyeBrowLeft.str.split(",",expand = True)
df[['t10','rightEyeBrowRightX','rightEyeBrowRightY']] = df.rightEyeBrowRight.str.split(",",expand = True)
df[['t11','rightEyeBrowupX','rightEyeBrowupY']] = df.rightEyeBrowup.str.split(",",expand = True)
df[['t12','leftEyeLeftX','leftEyeLeftY']] = df.leftEyeLeft.str.split(",",expand = True)
df[['t13','leftEyeRightX','leftEyeRightY']] = df.leftEyeRight.str.split(",",expand = True)
df[['t14','leftEyeUpX','leftEyeUpY']] = df.leftEyeUp.str.split(",",expand = True)
df[['t15','leftEyeDownX','leftEyeDownY']] = df.leftEyeDown.str.split(",",expand = True)
df[['t16','rightEyeLeftX','rightEyeLeftY']] = df.rightEyeLeft.str.split(",",expand = True)
df[['t17','rightEyeRightX','rightEyeRightY']] = df.rightEyeRight.str.split(",",expand = True)
df[['t18','rightEyeUpX','rightEyeUpY']] = df.rightEyeUp.str.split(",",expand = True)
df[['t19','rightEyeDownX','rightEyeDownY']] = df.rightEyeDown.str.split(",",expand = True)
df[['t20','noseLeftX','noseLeftY']] = df.noseLeft.str.split(",",expand = True)
df[['t21','noseRightX','noseRightY']] = df.noseRight.str.split(",",expand = True)
df[['t22','mouthUpX','mouthUpY']] = df.mouthUp.str.split(",",expand = True)
df[['t23','mouthDownX','mouthDownY']] = df.mouthDown.str.split(",",expand = True)
df[['t24','leftPupilX','leftPupilY']] = df.leftPupil.str.split(",",expand = True)
df[['t25','rightPupilX','rightPupilY']] = df.rightPupil.str.split(",",expand = True)
df[['t26','upperJawlineLeftX','upperJawlineLeftY']] = df.upperJawlineLeft.str.split(",",expand = True)
df[['t27','midJawlineLeftX','midJawlineLeftY']] = df.midJawlineLeft.str.split(",",expand = True)
df[['t28','chinBottomX','chinBottomY']] = df.chinBottom.str.split(",",expand = True)    
df[['t29','midJawlineRightX','midJawlineRightY']] = df.midJawlineRight.str.split(",",expand = True)
df[['t30','upperJawlineRightX','upperJawlineRightY']] = df.upperJawlineRight.str.split(",",expand = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[k1] = value[k2]

# %%
df = df.drop(['t1', 't2','t3','t4', 't5','t6','t7', 't8','t9','t10', 't11','t12','t13', 't14','t15','t16', 't17','t18','t19', 't20','t21','t22', 't23','t24','t25', 't26','t27','t28', 't29','t30'], axis=1)

# %%
for row in range(len(df['BoundingBoxHeight'])):
    
    df['eyeLeftX'][row]= re.sub("[^\d\.]","",df['eyeLeftX'][row])
    df['eyeLeftY'][row] = re.sub("[^\d\.]","",df['eyeLeftY'][row])
    df['eyeRightX'][row] = re.sub("[^\d\.]","",df['eyeRightX'][row])
    df['eyeRightY'][row] = re.sub("[^\d\.]","",df['eyeRightY'][row])
    df['mouthLeftX'][row] = re.sub("[^\d\.]","",df['mouthLeftX'][row])
    df['mouthLeftY'][row] = re.sub("[^\d\.]","",df['mouthLeftY'][row])
    df['mouthRightX'][row] = re.sub("[^\d\.]","",df['mouthRightX'][row])
    df['mouthRightY'][row] = re.sub("[^\d\.]","",df['mouthRightY'][row])
    df['noseX'][row] = re.sub("[^\d\.]","",df['noseX'][row])
    df['noseY'][row] = re.sub("[^\d\.]","", df['noseY'][row])
    df['leftEyeBrowLeftX'][row] = re.sub("[^\d\.]","",df['leftEyeBrowLeftX'][row] )
    df['leftEyeBrowLeftY'][row]=re.sub("[^\d\.]","",df['leftEyeBrowLeftY'][row]) 
    df['leftEyeBrowRightX'][row] = re.sub("[^\d\.]","",df['leftEyeBrowRightX'][row])
    df['leftEyeBrowRightY'][row] =re.sub("[^\d\.]","",df['leftEyeBrowRightY'][row]) 
    df['leftEyeBrowUpX'][row] = re.sub("[^\d\.]","",df['leftEyeBrowUpX'][row])
    df['leftEyeBrowUpY'][row] = re.sub("[^\d\.]","",df['leftEyeBrowUpY'][row])
    df['rightEyeBrowLeftX'][row] = re.sub("[^\d\.]","",df['rightEyeBrowLeftX'][row])
    df['rightEyeBrowLeftY'][row] = re.sub("[^\d\.]","",df['rightEyeBrowLeftY'][row])
    df['rightEyeBrowRightX'][row] = re.sub("[^\d\.]","",df['rightEyeBrowRightX'][row] )
    df['rightEyeBrowRightY'][row] = re.sub("[^\d\.]","", df['rightEyeBrowRightY'][row])
    df['rightEyeBrowupX'][row] = re.sub("[^\d\.]","",df['rightEyeBrowupX'][row])
    df['rightEyeBrowupY'][row] = re.sub("[^\d\.]","",df['rightEyeBrowupY'][row])
    df['leftEyeLeftX'][row] = re.sub("[^\d\.]","",df['leftEyeLeftX'][row] )
    df['leftEyeLeftY'][row] = re.sub("[^\d\.]","",df['leftEyeLeftY'][row])
    df['leftEyeRightX'][row] = re.sub("[^\d\.]","",df['leftEyeRightX'][row])
    df['leftEyeRightY'][row] = re.sub("[^\d\.]","",df['leftEyeRightY'][row] )
    df['leftEyeUpX'][row] = re.sub("[^\d\.]","", df['leftEyeUpX'][row] )
    df['leftEyeUpY'][row] = re.sub("[^\d\.]","", df['leftEyeUpY'][row])
    df['leftEyeDownX'][row] = re.sub("[^\d\.]","",df['leftEyeDownX'][row] )
    df['leftEyeDownY'][row]= re.sub("[^\d\.]","",  df['leftEyeDownY'][row])
    df['rightEyeLeftX'][row] = re.sub("[^\d\.]","", df['rightEyeLeftX'][row])
    df['rightEyeLeftY'][row] = re.sub("[^\d\.]","",df['rightEyeLeftY'][row])
    df['rightEyeRightX'][row] = re.sub("[^\d\.]","", df['rightEyeRightX'][row])
    df['rightEyeRightY'][row] = re.sub("[^\d\.]","",df['rightEyeRightY'][row])
    df['rightEyeUpX'][row] = re.sub("[^\d\.]","",df['rightEyeUpX'][row])
    df['rightEyeUpY'][row] = re.sub("[^\d\.]","",df['rightEyeUpY'][row])
    df['rightEyeDownX'][row] = re.sub("[^\d\.]","",df['rightEyeDownX'][row])
    df['rightEyeDownY'][row] = re.sub("[^\d\.]","",df['rightEyeDownY'][row])
    df['noseLeftX'][row] = re.sub("[^\d\.]","",df['noseLeftX'][row])
    df['noseLeftY'][row] =re.sub("[^\d\.]","",df['noseLeftY'][row])
    df['noseRightX'][row] = re.sub("[^\d\.]","", df['noseRightX'][row])
    df['noseRightY'][row] = re.sub("[^\d\.]","", df['noseRightY'][row] )
    df['mouthUpX'][row] = re.sub("[^\d\.]","",df['mouthUpX'][row])
    df['mouthUpY'][row] = re.sub("[^\d\.]","",df['mouthUpY'][row])
    df['mouthDownX'][row] = re.sub("[^\d\.]","",df['mouthDownX'][row])
    df['mouthDownY'][row] = re.sub("[^\d\.]","", df['mouthDownY'][row])
    df['leftPupilX'][row] = re.sub("[^\d\.]","", df['leftPupilX'][row])
    df['leftPupilY'][row] = re.sub("[^\d\.]","",df['leftPupilY'][row])
    df['rightPupilX'][row] = re.sub("[^\d\.]","",df['rightPupilX'][row])
    df['rightPupilY'][row] = re.sub("[^\d\.]","", df['rightPupilY'][row] )
    df['upperJawlineLeftX'][row] = re.sub("[^\d\.]","",df['upperJawlineLeftX'][row])
    df['upperJawlineLeftY'][row] = re.sub("[^\d\.]","", df['upperJawlineLeftY'][row])
    df['midJawlineLeftX'][row] = re.sub("[^\d\.]","",df['midJawlineLeftX'][row])
    df['midJawlineLeftY'][row] = re.sub("[^\d\.]","",df['midJawlineLeftY'][row])
    df['chinBottomX'][row] = re.sub("[^\d\.]","",df['chinBottomX'][row])
    df['chinBottomY'][row] = re.sub("[^\d\.]","", df['chinBottomY'][row] )    
    df['midJawlineRightX'][row] = re.sub("[^\d\.]","",df['midJawlineRightX'][row])
    df['midJawlineRightY'][row] = re.sub("[^\d\.]","",df['midJawlineRightY'][row] )
    df['upperJawlineRightX'][row] = re.sub("[^\d\.]","", df['upperJawlineRightX'][row])
    df['upperJawlineRightY'][row] = re.sub("[^\d\.]","",df['upperJawlineRightY'][row])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df[['PoseRoll','PoseYaw','PosePitch']] = df.Pose.str.split(",",expand = True)

# %%
for row in range(len(df['BoundingBoxHeight'])): 
    df['PoseRoll'][row] = df['PoseRoll'][row].split(':')[-1]
    df['PoseYaw'][row] = df['PoseYaw'][row].split(':')[-1]
    df['PosePitch'][row] = df['PosePitch'][row].split(':')[-1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df[['QualityBrightness','QualitySharpness']] = df.Quality.str.split(",",expand = True)
for row in range(len(df['BoundingBoxHeight'])): 
    df['QualityBrightness'][row] = df['QualityBrightness'][row].split(':')[-1]
    df['QualitySharpness'][row] = df['QualitySharpness'][row].split(':')[-1]
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                             FileName  \
# 0    user_22/IMG_20210820_123021.jpg
# 1    user_22/IMG_20210820_123023.jpg
# 2    user_22/IMG_20210821_184544.jpg
# 3    user_22/IMG_20210821_184556.jpg
# 4    user_22/IMG_20210821_184557.jpg
# ...

# %%
for row in range(len(df['BoundingBoxHeight'])):
    
    df['QualitySharpness'][row]= re.sub("[^\d\.]","",df['QualitySharpness'][row])
    df['PosePitch'][row] = re.sub("[^\d\.]","",df['PosePitch'][row])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df.to_csv('/content/drive/MyDrive/InputFolder/NewData/Output2/user_'+str(user_no)+'.csv',index=False)

# %%
df
# Out:
#                             FileName  \
# 0    user_22/IMG_20210820_123021.jpg
# 1    user_22/IMG_20210820_123023.jpg
# 2    user_22/IMG_20210821_184544.jpg
# 3    user_22/IMG_20210821_184556.jpg
# 4    user_22/IMG_20210821_184557.jpg
# ..                               ...
# 404  user_22/IMG_20220407_124647.jpg
# 405  user_22/IMG_20220407_124648.jpg
# 406  user_22/IMG_20220407_153413.jpg
# 407  user_22/IMG_20220407_213215.jpg
# 408  user_22/IMG_20220407_213216.jpg
#
#                                            BoundingBox  \
# 0    {'Width': 0.32883480191230774, 'Height': 0.355...
# 1    {'Width': 0.34279727935791016, 'Height': 0.365...
# 2    {'Width': 0.24113738536834717, 'Height': 0.221...
# 3    {'Width': 0.26312026381492615, 'Height': 0.225...
# 4    {'Width': 0.2710522711277008, 'Height': 0.2264...
# ..                                                 ...
# 404  {'Width': 0.3996994197368622, 'Height': 0.3933...
# 405  {'Width': 0.3458857238292694, 'Height': 0.3317...
# ...

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(enc_df_concat.drop(['PredictedEmotion','Target'],axis = 'columns'),enc_df_concat['Target'],test_size=0.2)

# %%
# from sklearn.ensemble import RandomForestClassifier
# model = RandomForestClassifier(n_estimators = 10)
# model.fit(x_train, y_train)

# %%
# model.score(x_test,y_test)
